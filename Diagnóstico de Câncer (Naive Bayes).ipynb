# %%
import pandas as pd

# %%
#Carregamento dos dados
dados = pd.read_excel('/content/drive/MyDrive/Dados/cancer patient data sets.xlsx')
dados
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %%
#Coletando uma coluna que não será relevante
del dados ['Patient Id']

# %%
#Vizualização dos dados
dados
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0     33       1              2            4             5
# 1     17       1              3            1             5
# 2     35       1              4            5             6
# 3     37       1              7            7             7
# 4     46       1              6            8             7
# ..   ...     ...            ...          ...           ...
# 995   44       1              6            7             7
# 996   37       2              6            8             7
# 997   25       2              4            5             6
# 998   18       2              6            8             7
# 999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                       4             3                     2              2
# 1                       3             4                     2              2
# ...

# %%
#Carregando bibliotecas para vizualização 
#gráfica e estatística 
import seaborn as srn
import statistics as sts

# %%
#Verificando se há valores faltantes (NaN)
dados.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %%
#Apresentação gráfica da classificação dos níveis de câncer
#Objetivo
srn.histplot(dados['Level']).set_title('Nível de Câncer')
# Out:
# Text(0.5, 1.0, 'Nível de Câncer')

# %%
#Obtendo os valores estatísticos dos atributos
dados.describe()

# %%
#Separando os atributos utilizáveis da classe Part.1
previsores = dados.iloc[:, 0:23].values
previsores

# %%
#Separando os atributos utilizáveis da classe Part.2
classe = dados.iloc[:, 23].values
classe

# %%
#Carregando as bibliotecas para aplicação do algoritmo
#Naive Bayes
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, accuracy_score
from yellowbrick.classifier import ConfusionMatrix

# %%
#Separando os valores em treino e teste
x_treino, x_teste, y_treino, y_teste = train_test_split(previsores,
                                                        classe,
                                                        test_size = 0.3,
                                                        random_state = 0)
x_teste

# %%
#Aplicando o algoritmo nas variaveis de treino
naive_bayes = GaussianNB()
naive_bayes.fit(x_treino, y_treino)
# Out:
# GaussianNB()

# %%
#Checando as previsões
previsoes = naive_bayes.predict(x_teste)
previsoes
# Out:
# array(['High', 'Medium', 'Medium', 'High', 'Low', 'Medium', 'Medium',
#        'Medium', 'Medium', 'Low', 'Low', 'High', 'Low', 'High', 'High',
#        'Low', 'High', 'Medium', 'Low', 'High', 'Medium', 'High', 'High',
#        'High', 'High', 'High', 'Low', 'High', 'High', 'Medium', 'High',
#        'Low', 'Low', 'High', 'Medium', 'Medium', 'Medium', 'Low',
#        'Medium', 'Low', 'Medium', 'High', 'Medium', 'High', 'Medium',
#        'Low', 'Low', 'Medium', 'High', 'High', 'High', 'Medium', 'Low',
#        'High', 'Medium', 'Medium', 'Low', 'Low', 'High', 'High', 'Low',
#        'High', 'Medium', 'High', 'Medium', 'Medium', 'Low', 'High',
#        'Medium', 'High', 'Medium', 'High', 'Medium', 'Medium', 'Medium',
#        'Low', 'Low', 'Medium', 'Medium', 'High', 'Medium', 'High', 'Low',
#        'High', 'High', 'Medium', 'Low', 'Medium', 'Low', 'High', 'Medium',
#        'Low', 'High', 'Low', 'Medium', 'Low', 'Medium', 'High', 'Low',
# ...

# %%
#Obtendo a matriz de confusão para checar a precisão
confusao = confusion_matrix (y_teste, previsoes)
confusao
# Out:
# array([[99,  0,  9],
#        [ 4, 87,  8],
#        [11,  0, 82]])

# %%
#Vizualizando a matriz de confusão
v = ConfusionMatrix(GaussianNB())
v.fit(x_treino, y_treino)
v.score(x_teste, y_teste)
v.poof()

# %%
#Checando o desempenho do algoritmo
taxa_acerto = accuracy_score (y_teste, previsoes)
taxa_acerto
# Out:
# 0.8933333333333333
